# %%
import os
#if you want to know current working dir
os.getcwd()
# if you want to list dir
os.listdir()
# Out:
# ['test_env.ipynb', 'test_game.py']

# %%
import numpy as np
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
sys.path.insert(0, parent_dir)
import lands_vars as lv
import lands_game as lg
import lands_env as le
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import sys
#       3 import os
# ----> 5 parent_dir = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
#       6 sys.path.insert(0, parent_dir)
#       7 import lands_vars as lv
#
# NameError: name '__file__' is not defined
